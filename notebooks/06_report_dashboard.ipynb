# %% [markdown]
# # 06 Report Dashboard (Optional)
#
# This notebook is a quick panel for report regeneration only.
#
# ## When to use it
# - when graph/criticality/inventory artifacts already exist
# - when you want to change report title or `Top K` and regenerate quickly
#
# ## What happens here
# - regenerate charts into `report/assets`
# - export the Markdown report and, when enabled, a PDF only if Pandoc creates a non-empty file
# - report a clear Markdown-only result when PDF conversion is unavailable
#
# ## How to use the panel
# - `Generate Charts`
# - `Export Report`
# - `Generate + Export`

# %% [markdown]
# ### Environment initialization
# Sets paths and initializes dashboard widgets.

# %%
from pathlib import Path
import os
import sys


def find_project_root(start: Path) -> Path:
    candidates = [start, *start.parents]

    env_root = os.environ.get("PMMAP_ROOT")
    if env_root:
        candidates.append(Path(env_root))

    seen = set()
    for path in candidates:
        try:
            path = path.resolve()
        except Exception:
            pass
        key = str(path)
        if key in seen:
            continue
        seen.add(key)
        if (path / "pmmap").is_dir():
            return path

    raise RuntimeError(
        "Could not locate project root (directory containing 'pmmap'). "
        "Open notebook from repository workspace or set PMMAP_ROOT."
    )


ROOT = find_project_root(Path().resolve())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from pmmap.notebook_common import init_notebook_paths

ROOT, DATA_DIR, RUN_DIR = init_notebook_paths(start=ROOT)

# %% [markdown]
# ### Report control panel
# Adjust report parameters and regenerate outputs.

# %%
from pmmap.notebook_widgets import create_report_dashboard

create_report_dashboard(
    run_dir=RUN_DIR,
    default_top_k=10,
    default_title="Passive Network Mapping Report",
)
